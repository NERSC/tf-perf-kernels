# %%
import pandas as pd
import os

# %%
datadir = "./results"
profiledf = pd.read_csv(os.path.join(datadir,"full_profile.csv"))
combineddf = pd.read_csv(os.path.join(datadir,"combined_profile.csv"))

# %%
pd.options.display.max_colwidth = 200
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "3x3x64x64") & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Precision", "Batch Size"] ] #,  "Kernel Shape", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              #]
# Out:
#                                                                                                                                                                                                         Name  \
# 1                                                                                                                                cudnn::gemm::computeWgradBOffsetsKernel(cudnn::gemm::ComputeBOffsetsParams)
# 2                                                                                                                            cudnn::gemm::computeWgradSplitKOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
# 3                                                                                                                            void scalePackedTensor_kernel<float, float>(cudnnTensor4dStruct, float*, float)
# ...

# %%
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "9x9x64x64") & (profiledf["Pass"] == "forward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Precision", "Batch Size"] ] #, "Kernel Shape", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              #]
# Out:
#                                                                                                                                                                                                         Name  \
# 104  void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*,...
# 105                           void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 106                           void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# ...

# %%
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "3x3x64x64") & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              ]
# Out:
#                                                   Name Kernel Shape Precision  \
# 1    cudnn::gemm::computeWgradBOffsetsKernel(cudnn:...    3x3x64x64      FP32
# 2    cudnn::gemm::computeWgradSplitKOffsetsKernel(c...    3x3x64x64      FP32
# 3    void scalePackedTensor_kernel<float, float>(cu...    3x3x64x64      FP32
# 4    void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP32
# 7    void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP32
# 9    void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP32
# 11   volta_scudnn_128x64_stridedB_splitK_interior_n...    3x3x64x64      FP32
# 117  void cudnn::detail::wgrad_alg0_engine<float, i...    3x3x64x64      FP32
# 118  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP32
# 120  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP32
# 123  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP32
# ...

# %%
#Hirarchy inversion issue
combineddf.loc[ (combineddf["Network Name"] == "ResNet50-2") & \
            (combineddf["Input Shape"] == "112x112x64") & (combineddf["Stride Size"] == 2) &\
            (combineddf["Kernel Shape"].str.startswith("3x3x64")) & (combineddf["Pass"] == "backward") & (combineddf["Precision"]=="FP32") & (combineddf["Batch Size"]==16),
            ["Kernel Shape", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              ]

##Fig 9 b
#profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
#            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
#            (profiledf["Kernel Shape"].str.startswith("3x3x64")) & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32") & (profiledf["Batch Size"]==16),
#            ["Name", "Kernel Shape", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "Shared Transactions Avg", "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
#              ]

# %%
# Fig 8a
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "3x3x64x64") & (profiledf["Pass"] == "forward") & (profiledf["Precision"]=="FP16"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
              ] #.to_csv(os.path.join(datadir,"paper_selected_bs_full.csv"))

# %%
# Fig 8b
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "3x3x64x64") & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
             ]

# %%
# Fig 10a
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & (profiledf["Batch Size"] == 16) & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"].str.endswith("64x64")) & (profiledf["Pass"] == "forward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
             ]

# %%
# Fig 10b
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & (profiledf["Batch Size"] == 16) & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"].str.endswith("64x64")) & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
             ]
