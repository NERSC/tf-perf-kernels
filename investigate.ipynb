# %%
import pandas as pd
import os

# %%
datadir = "./results"
profiledf = pd.read_csv(os.path.join(datadir,"full_profile.csv"))
combineddf = pd.read_csv(os.path.join(datadir,"combined_profile.csv"))

# %%
combineddf.loc[ (combineddf["Network Name"] == "ResNet50-2") & \
            (combineddf["Input Shape"] == "112x112x64") & (combineddf["Stride Size"] == 2), ["Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              ].to_csv(os.path.join(datadir,"paper_selected.csv"))

# %%
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "3x3x64x64") & (profiledf["Pass"] == "forward") & (profiledf["Precision"]=="FP16"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              ]
# Out:
#                                                   Name Kernel Shape Precision  \
# 208  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    3x3x64x64      FP16
# 211  void nchwToNhwcKernel<__half, __half, float, b...    3x3x64x64      FP16
# 215  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP16
# 217  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP16
# 218  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP16
# 220  volta_fp16_s884cudnn_fp16_256x64_ldg8_relu_f2f...    3x3x64x64      FP16
# 222  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    3x3x64x64      FP16
# 226  void nchwToNhwcKernel<__half, __half, float, b...    3x3x64x64      FP16
# 230  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP16
# 232  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP16
# 233  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP16
# 235  volta_fp16_s884cudnn_fp16_256x64_ldg8_relu_f2f...    3x3x64x64      FP16
# 237  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    3x3x64x64      FP16
# 241  void nchwToNhwcKernel<__half, __half, float, b...    3x3x64x64      FP16
# 245  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP16
# 246  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP16
# 248  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP16
# 250  volta_fp16_s884cudnn_fp16_256x64_ldg8_relu_f2f...    3x3x64x64      FP16
#
#      Batch Size  Time Avg     Flops Avg  TC Flops Avg  FP16 non-TC Flops Avg  \
# 208          16  0.000001  0.000000e+00  0.000000e+00                    0.0
# 211          16  0.000038  1.311232e+07  0.000000e+00              6556160.0
# 215          16  0.000216  0.000000e+00  0.000000e+00                    0.0
# 217          16  0.000003  0.000000e+00  0.000000e+00                    0.0
# 218          16  0.000052  0.000000e+00  0.000000e+00                    0.0
# 220          16  0.000118  7.378386e+09  7.371562e+09               401408.0
# 222          32  0.000001  0.000000e+00  0.000000e+00                    0.0
# 226          32  0.000073  2.618778e+07  0.000000e+00             13093888.0
# 230          32  0.000428  0.000000e+00  0.000000e+00                    0.0
# 232          32  0.000003  0.000000e+00  0.000000e+00                    0.0
# 233          32  0.000101  0.000000e+00  0.000000e+00                    0.0
# 235          32  0.000188  1.174509e+10  1.173144e+10               802816.0
# 237          64  0.000001  0.000000e+00  0.000000e+00                    0.0
# 241          64  0.000143  5.233869e+07  0.000000e+00             26169344.0
# 245          64  0.000852  0.000000e+00  0.000000e+00                    0.0
# 246          64  0.000003  0.000000e+00  0.000000e+00                    0.0
# 248          64  0.000199  0.000000e+00  0.000000e+00                    0.0
# 250          64  0.000331  1.657355e+10  1.654625e+10              1605632.0
#
#      FP32 Flops Avg  L1 Transactions Avg  L2 Transactions Avg  \
# 208             0.0                688.0                822.0
# 211       6556160.0            1013360.0            1019193.0
# 215             0.0            1620032.0            1679995.0
# 217             0.0              39168.0              24700.0
# 218             0.0            1209920.0            1289552.0
# 220       6422528.0            2463963.0            2431255.0
# 222             0.0                688.0                822.0
# 226      13093888.0            2022495.0            2028094.0
# 230             0.0            3240064.0            3298410.0
# 232             0.0              39168.0              24874.0
# 233             0.0            2419840.0            2590654.0
# 235      12845056.0            4928196.0            4881100.0
# 237             0.0                688.0                822.0
# 241      26169344.0            4040761.0            4045802.0
# 245             0.0            6480128.0            6539287.0
# 246             0.0              39168.0              24858.0
# 248             0.0            4839680.0            5190912.0
# 250      25690112.0            9857767.0            9768501.0
#
#      DRAM Transactions Avg
# 208                  202.0
# 211               823980.0
# 215              1689602.0
# 217                 8927.0
# 218              1075222.0
# 220              1867671.0
# 222                  209.0
# 226              1640802.0
# 230              3308544.0
# 232                 8686.0
# 233              2197174.0
# 235              3790196.0
# 237                  205.0
# 241              3275422.0
# 245              6551562.0
# 246                 8876.0
# 248              4427881.0
# 250              7873378.0

# %%
combineddf.loc[ (combineddf["Network Name"] == "ResNet50-2") & \
            (combineddf["Input Shape"] == "112x112x64") & (combineddf["Stride Size"] == 2) &\
            (combineddf["Kernel Shape"] == "3x3x64x64") & (combineddf["Pass"] == "forward") & (combineddf["Precision"]=="FP16"),
            ["Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              ]
# Out:
#    Kernel Shape Precision  Batch Size  Time Avg     Flops Avg  TC Flops Avg  \
# 31    3x3x64x64      FP16          16  0.000428  7.391499e+09  7.371562e+09
# 33    3x3x64x64      FP16          32  0.000794  1.177127e+10  1.173144e+10
# 35    3x3x64x64      FP16          64  0.001530  1.662588e+10  1.654625e+10
#
#     FP16 non-TC Flops Avg  FP32 Flops Avg  L1 Transactions Avg  \
# 31              6957568.0      12978688.0            6347131.0
# 33             13896704.0      25938944.0           12650451.0
# 35             27774976.0      51859456.0           25258192.0
#
#     L2 Transactions Avg  DRAM Transactions Avg
# 31            6445517.0              5465604.0
# 33           12823954.0             10945611.0
# 35           25570182.0             22137324.0

# %%
#Hirarchy inversion issue
#combineddf.loc[ (combineddf["Network Name"] == "ResNet50-2") & \
#            (combineddf["Input Shape"] == "112x112x64") & (combineddf["Stride Size"] == 2) &\
#            (combineddf["Kernel Shape"].str.startswith("3x3x64")) & (combineddf["Pass"] == "backward") & (combineddf["Precision"]=="FP32") & (combineddf["Batch Size"]==16),
#            ["Kernel Shape", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
#              ]

#Fig 9 b
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"].str.startswith("3x3x64")) & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32") & (profiledf["Batch Size"]==16),
            ["Name", "Kernel Shape", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg"]
              ]
# Out:
#                                                   Name Kernel Shape  Time Avg  \
# 538  void cudnn::detail::wgrad_alg0_engine<float, i...   3x3x64x128  0.000786
# 539  void tensorflow::functor::PadInputCustomKernel...   3x3x64x128  0.000231
# 542  void tensorflow::functor::ShuffleInTensor3Simp...   3x3x64x128  0.000004
# 544  void tensorflow::functor::SwapDimension1And2In...   3x3x64x128  0.000128
# 575  cudnn::gemm::computeWgradBOffsetsKernel(cudnn:...   3x3x64x256  0.000001
# 576  cudnn::gemm::computeWgradSplitKOffsetsKernel(c...   3x3x64x256  0.000002
# 577  void scalePackedTensor_kernel<float, float>(cu...   3x3x64x256  0.000002
# 578  void tensorflow::functor::PadInputCustomKernel...   3x3x64x256  0.000231
# 580  void tensorflow::functor::ShuffleInTensor3Simp...   3x3x64x256  0.000005
# 583  void tensorflow::functor::SwapDimension1And2In...   3x3x64x256  0.000128
# 585  volta_scudnn_128x64_stridedB_splitK_interior_n...   3x3x64x256  0.001425
# 621  cudnn::gemm::computeWgradBOffsetsKernel(cudnn:...   3x3x64x512  0.000001
# 622  cudnn::gemm::computeWgradSplitKOffsetsKernel(c...   3x3x64x512  0.000002
# 623  void scalePackedTensor_kernel<float, float>(cu...   3x3x64x512  0.000003
# 624  void tensorflow::functor::PadInputCustomKernel...   3x3x64x512  0.000231
# 626  void tensorflow::functor::ShuffleInTensor3Simp...   3x3x64x512  0.000009
# 629  void tensorflow::functor::SwapDimension1And2In...   3x3x64x512  0.000128
# 631  volta_scudnn_128x64_stridedB_splitK_interior_n...   3x3x64x512  0.002653
# 655  void cudnn::detail::wgrad_alg0_engine<float, i...    3x3x64x64  0.000490
# 656  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64  0.000231
# 659  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64  0.000003
# 661  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64  0.000129
#
#         Flops Avg  TC Flops Avg  FP16 non-TC Flops Avg  FP32 Flops Avg  \
# 538  7.407010e+09           0.0                    0.0    7.407010e+09
# 539  0.000000e+00           0.0                    0.0    0.000000e+00
# 542  0.000000e+00           0.0                    0.0    0.000000e+00
# 544  0.000000e+00           0.0                    0.0    0.000000e+00
# 575  0.000000e+00           0.0                    0.0    0.000000e+00
# 576  0.000000e+00           0.0                    0.0    0.000000e+00
# 577  0.000000e+00           0.0                    0.0    0.000000e+00
# 578  0.000000e+00           0.0                    0.0    0.000000e+00
# 580  0.000000e+00           0.0                    0.0    0.000000e+00
# 583  0.000000e+00           0.0                    0.0    0.000000e+00
# 585  1.646920e+10           0.0                    0.0    1.646920e+10
# 621  0.000000e+00           0.0                    0.0    0.000000e+00
# 622  0.000000e+00           0.0                    0.0    0.000000e+00
# 623  0.000000e+00           0.0                    0.0    0.000000e+00
# 624  0.000000e+00           0.0                    0.0    0.000000e+00
# 626  0.000000e+00           0.0                    0.0    0.000000e+00
# 629  0.000000e+00           0.0                    0.0    0.000000e+00
# 631  3.293839e+10           0.0                    0.0    3.293839e+10
# 655  3.703505e+09           0.0                    0.0    3.703505e+09
# 656  0.000000e+00           0.0                    0.0    0.000000e+00
# 659  0.000000e+00           0.0                    0.0    0.000000e+00
# 661  0.000000e+00           0.0                    0.0    0.000000e+00
#
#      L1 Transactions Avg  L2 Transactions Avg  DRAM Transactions Avg
# 538           12258464.0           17984119.0              2896454.0
# 539            3451071.0            3310519.0              3294181.0
# 542              82809.0              83080.0                   10.0
# 544            3211264.0            3211474.0              3220603.0
# 575                  8.0                 43.0                   33.0
# 576                308.0                439.0                  155.0
# 577              18432.0              18555.0                10014.0
# 578            3450876.0            3310794.0              3291664.0
# 580             164797.0             120111.0                   10.0
# 583            3211264.0            3211467.0              3220529.0
# 585           59984611.0           23839237.0              4405077.0
# 621                  8.0                 43.0                   33.0
# 622                308.0                439.0                  178.0
# 623              36864.0              36985.0                26240.0
# 624            3450492.0            3310602.0              3291839.0
# 626             315963.0             294372.0                   20.0
# 629            3211264.0            3211468.0              3221074.0
# 631          118791116.0           47487341.0              8894002.0
# 655           24626259.0           13649772.0              4842741.0
# 656            3449209.0            3309308.0              3292351.0
# 659              41461.0              41608.0                   10.0
# 661            3211264.0            3211470.0              3220704.0

# %%
# Fig 8a
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "3x3x64x64") & (profiledf["Pass"] == "forward") & (profiledf["Precision"]=="FP16"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
              ] #.to_csv(os.path.join(datadir,"paper_selected_bs_full.csv"))
# Out:
#                                                   Name Kernel Shape Precision  \
# 208  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    3x3x64x64      FP16
# 211  void nchwToNhwcKernel<__half, __half, float, b...    3x3x64x64      FP16
# 215  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP16
# 217  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP16
# 218  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP16
# 220  volta_fp16_s884cudnn_fp16_256x64_ldg8_relu_f2f...    3x3x64x64      FP16
# 222  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    3x3x64x64      FP16
# 226  void nchwToNhwcKernel<__half, __half, float, b...    3x3x64x64      FP16
# 230  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP16
# 232  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP16
# 233  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP16
# 235  volta_fp16_s884cudnn_fp16_256x64_ldg8_relu_f2f...    3x3x64x64      FP16
# 237  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    3x3x64x64      FP16
# 241  void nchwToNhwcKernel<__half, __half, float, b...    3x3x64x64      FP16
# 245  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP16
# 246  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP16
# 248  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP16
# 250  volta_fp16_s884cudnn_fp16_256x64_ldg8_relu_f2f...    3x3x64x64      FP16
#
#      Batch Size  Time Avg     Flops Avg  TC Flops Avg  FP16 non-TC Flops Avg  \
# 208          16  0.000001  0.000000e+00  0.000000e+00                    0.0
# 211          16  0.000038  1.311232e+07  0.000000e+00              6556160.0
# 215          16  0.000216  0.000000e+00  0.000000e+00                    0.0
# 217          16  0.000003  0.000000e+00  0.000000e+00                    0.0
# 218          16  0.000052  0.000000e+00  0.000000e+00                    0.0
# 220          16  0.000118  7.378386e+09  7.371562e+09               401408.0
# 222          32  0.000001  0.000000e+00  0.000000e+00                    0.0
# 226          32  0.000073  2.618778e+07  0.000000e+00             13093888.0
# 230          32  0.000428  0.000000e+00  0.000000e+00                    0.0
# 232          32  0.000003  0.000000e+00  0.000000e+00                    0.0
# 233          32  0.000101  0.000000e+00  0.000000e+00                    0.0
# 235          32  0.000188  1.174509e+10  1.173144e+10               802816.0
# 237          64  0.000001  0.000000e+00  0.000000e+00                    0.0
# 241          64  0.000143  5.233869e+07  0.000000e+00             26169344.0
# 245          64  0.000852  0.000000e+00  0.000000e+00                    0.0
# 246          64  0.000003  0.000000e+00  0.000000e+00                    0.0
# 248          64  0.000199  0.000000e+00  0.000000e+00                    0.0
# 250          64  0.000331  1.657355e+10  1.654625e+10              1605632.0
#
#      FP32 Flops Avg  L1 Transactions Avg  L2 Transactions Avg  \
# 208             0.0                688.0                822.0
# 211       6556160.0            1013360.0            1019193.0
# 215             0.0            1620032.0            1679995.0
# 217             0.0              39168.0              24700.0
# 218             0.0            1209920.0            1289552.0
# 220       6422528.0            2463963.0            2431255.0
# 222             0.0                688.0                822.0
# 226      13093888.0            2022495.0            2028094.0
# 230             0.0            3240064.0            3298410.0
# 232             0.0              39168.0              24874.0
# 233             0.0            2419840.0            2590654.0
# 235      12845056.0            4928196.0            4881100.0
# 237             0.0                688.0                822.0
# 241      26169344.0            4040761.0            4045802.0
# 245             0.0            6480128.0            6539287.0
# 246             0.0              39168.0              24858.0
# 248             0.0            4839680.0            5190912.0
# 250      25690112.0            9857767.0            9768501.0
#
#      DRAM Transactions Avg     DRAM AI
# 208                  202.0    0.000000
# 211               823980.0    0.497294
# 215              1689602.0    0.000000
# 217                 8927.0    0.000000
# 218              1075222.0    0.000000
# 220              1867671.0  123.455671
# 222                  209.0    0.000000
# 226              1640802.0    0.498761
# 230              3308544.0    0.000000
# 232                 8686.0    0.000000
# 233              2197174.0    0.000000
# 235              3790196.0   96.837714
# 237                  205.0    0.000000
# 241              3275422.0    0.499351
# 245              6551562.0    0.000000
# 246                 8876.0    0.000000
# 248              4427881.0    0.000000
# 250              7873378.0   65.781588

# %%
# Fig 8b
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"] == "3x3x64x64") & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
             ]
# Out:
#                                                   Name Kernel Shape Precision  \
# 655  void cudnn::detail::wgrad_alg0_engine<float, i...    3x3x64x64      FP32
# 656  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP32
# 659  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP32
# 661  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP32
# 664  void cudnn::detail::wgrad_alg0_engine<float, i...    3x3x64x64      FP32
# 665  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP32
# 668  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP32
# 670  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP32
# 673  cudnn::gemm::computeWgradBOffsetsKernel(cudnn:...    3x3x64x64      FP32
# 674  cudnn::gemm::computeWgradSplitKOffsetsKernel(c...    3x3x64x64      FP32
# 675  void scalePackedTensor_kernel<float, float>(cu...    3x3x64x64      FP32
# 676  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP32
# 678  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP32
# 681  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP32
# 683  volta_scudnn_128x64_stridedB_splitK_interior_n...    3x3x64x64      FP32
#
#      Batch Size  Time Avg     Flops Avg  TC Flops Avg  FP16 non-TC Flops Avg  \
# 655          16  0.000490  3.703505e+09           0.0                    0.0
# 656          16  0.000231  0.000000e+00           0.0                    0.0
# 659          16  0.000003  0.000000e+00           0.0                    0.0
# 661          16  0.000129  0.000000e+00           0.0                    0.0
# 664          32  0.000932  7.407010e+09           0.0                    0.0
# 665          32  0.000452  0.000000e+00           0.0                    0.0
# 668          32  0.000003  0.000000e+00           0.0                    0.0
# 670          32  0.000255  0.000000e+00           0.0                    0.0
# 673          64  0.000001  0.000000e+00           0.0                    0.0
# 674          64  0.000002  0.000000e+00           0.0                    0.0
# 675          64  0.000001  0.000000e+00           0.0                    0.0
# 676          64  0.000896  0.000000e+00           0.0                    0.0
# 678          64  0.000003  0.000000e+00           0.0                    0.0
# 681          64  0.000502  0.000000e+00           0.0                    0.0
# 683          64  0.001640  1.644855e+10           0.0                    0.0
#
#      FP32 Flops Avg  L1 Transactions Avg  L2 Transactions Avg  \
# 655    3.703505e+09           24626259.0           13649772.0
# 656    0.000000e+00            3449209.0            3309308.0
# 659    0.000000e+00              41461.0              41608.0
# 661    0.000000e+00            3211264.0            3211470.0
# 664    7.407010e+09           49246058.0           27306107.0
# 665    0.000000e+00            6905615.0            6687195.0
# 668    0.000000e+00              41461.0              41608.0
# 670    0.000000e+00            6422528.0            6422732.0
# 673    0.000000e+00                  8.0                 43.0
# 674    0.000000e+00                308.0                439.0
# 675    0.000000e+00               4608.0               4729.0
# 676    0.000000e+00           13834317.0           13531471.0
# 678    0.000000e+00              41461.0              41608.0
# 681    0.000000e+00           12845056.0           12845259.0
# 683    1.644855e+10           57960989.0           22113784.0
#
#      DRAM Transactions Avg    DRAM AI
# 655              4842741.0  23.898558
# 656              3292351.0   0.000000
# 659                   10.0   0.000000
# 661              3220704.0   0.000000
# 664             10499622.0  22.045466
# 665              6681293.0   0.000000
# 668                   10.0   0.000000
# 670              6432801.0   0.000000
# 673                   13.0   0.000000
# 674                  163.0   0.000000
# 675                 1633.0   0.000000
# 676             13726003.0   0.000000
# 678                   10.0   0.000000
# 681             12855823.0   0.000000
# 683              9386354.0  54.762188

# %%
# Fig 10a
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & (profiledf["Batch Size"] == 16) & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"].str.endswith("64x64")) & (profiledf["Pass"] == "forward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
             ]
# Out:
#                                                   Name Kernel Shape Precision  \
# 654  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    3x3x64x64      FP32
# 657  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP32
# 658  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP32
# 660  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP32
# 662            volta_scudnn_128x64_relu_interior_nn_v1    3x3x64x64      FP32
# 704  cudnn::gemm::computeOffsetsKernel(cudnn::gemm:...    7x7x64x64      FP32
# 709  void tensorflow::functor::PadInputCustomKernel...    7x7x64x64      FP32
# 711  void tensorflow::functor::ShuffleInTensor3Simp...    7x7x64x64      FP32
# 712  void tensorflow::functor::SwapDimension1And2In...    7x7x64x64      FP32
# 714              volta_scudnn_128x64_relu_medium_nn_v1    7x7x64x64      FP32
# 751  void fft2d_c2r_32x32<float, bool=1, bool=0, un...    9x9x64x64      FP32
# 752  void fft2d_r2c_32x32<float, bool=0, unsigned i...    9x9x64x64      FP32
# 753  void fft2d_r2c_32x32<float, bool=0, unsigned i...    9x9x64x64      FP32
# 755  void tensorflow::functor::PadInputCustomKernel...    9x9x64x64      FP32
# 757  void tensorflow::functor::ShuffleInTensor3Simp...    9x9x64x64      FP32
# 758  void tensorflow::functor::SwapDimension1And2In...    9x9x64x64      FP32
# 760                              volta_gcgemm_32x32_nt    9x9x64x64      FP32
#
#      Batch Size  Time Avg     Flops Avg  TC Flops Avg  FP16 non-TC Flops Avg  \
# 654          16  0.000001  0.000000e+00           0.0                    0.0
# 657          16  0.000229  0.000000e+00           0.0                    0.0
# 658          16  0.000004  0.000000e+00           0.0                    0.0
# 660          16  0.000094  0.000000e+00           0.0                    0.0
# 662          16  0.000354  3.705799e+09           0.0                    0.0
# 704          16  0.000001  0.000000e+00           0.0                    0.0
# 709          16  0.000229  0.000000e+00           0.0                    0.0
# 711          16  0.000007  0.000000e+00           0.0                    0.0
# 712          16  0.000093  0.000000e+00           0.0                    0.0
# 714          16  0.001914  2.014747e+10           0.0                    0.0
# 751          16  0.000022  2.274472e+07           0.0                    0.0
# 752          16  0.000029  2.311782e+07           0.0                    0.0
# 753          16  0.000053  9.247130e+07           0.0                    0.0
# 755          16  0.000229  0.000000e+00           0.0                    0.0
# 757          16  0.000011  0.000000e+00           0.0                    0.0
# 758          16  0.000093  0.000000e+00           0.0                    0.0
# 760          16  0.000062  4.442522e+08           0.0                    0.0
#
#      FP32 Flops Avg  L1 Transactions Avg  L2 Transactions Avg  \
# 654    0.000000e+00                688.0                887.0
# 657    0.000000e+00            3240064.0            3240229.0
# 658    0.000000e+00              41472.0              28825.0
# 660    0.000000e+00            2215040.0            2348888.0
# 662    3.705799e+09           10204084.0            4050896.0
# 704    0.000000e+00                688.0                119.0
# 709    0.000000e+00            3240064.0            3240236.0
# 711    0.000000e+00             224050.0             233641.0
# 712    0.000000e+00            2215040.0            2350626.0
# 714    2.014747e+10             401408.0           12066782.0
# 751    2.274472e+07             159907.0             163206.0
# 752    2.311782e+07             272896.0             283433.0
# 753    9.247130e+07             604786.0             625706.0
# 755    0.000000e+00            3240064.0            3240362.0
# 757    0.000000e+00             373248.0             386238.0
# 758    0.000000e+00            2215040.0            2350099.0
# 760    4.442522e+08             974848.0             951793.0
#
#      DRAM Transactions Avg      DRAM AI
# 654                  354.0     0.000000
# 657              3263031.0     0.000000
# 658                10579.0     0.000000
# 660              2165784.0     0.000000
# 662              2138237.0    54.159669
# 704                  504.0     0.000000
# 709              3262883.0     0.000000
# 711                62240.0     0.000000
# 712              2166936.0     0.000000
# 714               419355.0  1501.373414
# 751               125569.0     5.660414
# 752               260053.0     2.778018
# 753               551723.0     5.237643
# 755              3262678.0     0.000000
# 757               107529.0     0.000000
# 758              2150607.0     0.000000
# 760               849261.0    16.347012

# %%
# Fig 10b
profiledf.loc[ (profiledf["Network Name"] == "ResNet50-2") & (profiledf["Batch Size"] == 16) & \
            (profiledf["Input Shape"] == "112x112x64") & (profiledf["Stride Size"] == 2) &\
            (profiledf["Kernel Shape"].str.endswith("64x64")) & (profiledf["Pass"] == "backward") & (profiledf["Precision"]=="FP32"),
            ["Name", "Kernel Shape", "Precision", "Batch Size", "Time Avg", 'Flops Avg', 'TC Flops Avg', 'FP16 non-TC Flops Avg', 'FP32 Flops Avg', "L1 Transactions Avg", "L2 Transactions Avg", "DRAM Transactions Avg", "DRAM AI"]
             ]
# Out:
#                                                   Name Kernel Shape Precision  \
# 655  void cudnn::detail::wgrad_alg0_engine<float, i...    3x3x64x64      FP32
# 656  void tensorflow::functor::PadInputCustomKernel...    3x3x64x64      FP32
# 659  void tensorflow::functor::ShuffleInTensor3Simp...    3x3x64x64      FP32
# 661  void tensorflow::functor::SwapDimension1And2In...    3x3x64x64      FP32
# 705  cudnn::gemm::computeWgradBOffsetsKernel(cudnn:...    7x7x64x64      FP32
# 706  cudnn::gemm::computeWgradSplitKOffsetsKernel(c...    7x7x64x64      FP32
# 707  void scalePackedTensor_kernel<float, float>(cu...    7x7x64x64      FP32
# 708  void tensorflow::functor::PadInputCustomKernel...    7x7x64x64      FP32
# 710  void tensorflow::functor::ShuffleInTensor3Simp...    7x7x64x64      FP32
# 713  void tensorflow::functor::SwapDimension1And2In...    7x7x64x64      FP32
# 715   volta_scudnn_128x64_stridedB_splitK_medium_nn_v1    7x7x64x64      FP32
# 750  void cudnn::detail::wgrad_alg0_engine<float, i...    9x9x64x64      FP32
# 754  void tensorflow::functor::PadInputCustomKernel...    9x9x64x64      FP32
# 756  void tensorflow::functor::ShuffleInTensor3Simp...    9x9x64x64      FP32
# 759  void tensorflow::functor::SwapDimension1And2In...    9x9x64x64      FP32
#
#      Batch Size  Time Avg     Flops Avg  TC Flops Avg  FP16 non-TC Flops Avg  \
# 655          16  0.000490  3.703505e+09           0.0                    0.0
# 656          16  0.000231  0.000000e+00           0.0                    0.0
# 659          16  0.000003  0.000000e+00           0.0                    0.0
# 661          16  0.000129  0.000000e+00           0.0                    0.0
# 705          16  0.000001  0.000000e+00           0.0                    0.0
# 706          16  0.000002  0.000000e+00           0.0                    0.0
# 707          16  0.000003  0.000000e+00           0.0                    0.0
# 708          16  0.000231  0.000000e+00           0.0                    0.0
# 710          16  0.000007  0.000000e+00           0.0                    0.0
# 713          16  0.000128  0.000000e+00           0.0                    0.0
# 715          16  0.001806  2.058650e+10           0.0                    0.0
# 750          16  0.003649  3.333154e+10           0.0                    0.0
# 754          16  0.000229  0.000000e+00           0.0                    0.0
# 756          16  0.000011  0.000000e+00           0.0                    0.0
# 759          16  0.000128  0.000000e+00           0.0                    0.0
#
#      FP32 Flops Avg  L1 Transactions Avg  L2 Transactions Avg  \
# 655    3.703505e+09           24626259.0           13649772.0
# 656    0.000000e+00            3449209.0            3309308.0
# 659    0.000000e+00              41461.0              41608.0
# 661    0.000000e+00            3211264.0            3211470.0
# 705    0.000000e+00                  8.0                 43.0
# 706    0.000000e+00                821.0                951.0
# 707    0.000000e+00              25088.0              25209.0
# 708    0.000000e+00            3450490.0            3309279.0
# 710    0.000000e+00             212763.0             225928.0
# 713    0.000000e+00            3211264.0            3211469.0
# 715    2.058650e+10           54446257.0           21185971.0
# 750    3.333154e+10          122205236.0           77490119.0
# 754    0.000000e+00            3450439.0            3310225.0
# 756    0.000000e+00             353826.0             373006.0
# 759    0.000000e+00            3211264.0            3211475.0
#
#      DRAM Transactions Avg     DRAM AI
# 655              4842741.0   23.898558
# 656              3292351.0    0.000000
# 659                   10.0    0.000000
# 661              3220704.0    0.000000
# 705                   29.0    0.000000
# 706                  696.0    0.000000
# 707                15211.0    0.000000
# 708              3292396.0    0.000000
# 710                   10.0    0.000000
# 713              3220369.0    0.000000
# 715              2950453.0  218.043805
# 750              2303654.0  452.155902
# 754              3293456.0    0.000000
# 756                  290.0    0.000000
# 759              3220999.0    0.000000
