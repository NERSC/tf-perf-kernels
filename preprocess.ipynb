# %%
import subprocess as sp
import numpy as np
import pandas as pd
from io import StringIO
import os
import re
import shutil

from utils import *

# %%
#global parameters
cudadir = "/usr/common/software/cuda/10.0.130"

# %%
#input and output dirs
datadirs = ["./data/tf_2.0b/good"] #,"./data/tf_2.0b/investigate"]
outputdir = "./data/tf_2.0b/sanitized"

# %% [markdown]
# # Functions

# %%
def compare_sets(set1, set2):
    good = True
    not_in_set1 = set()
    not_in_set2 = set()
    for item in set1:
        if item in set2:
            set2.remove(item)
        else:
            #print(item, "in set1 but not in set2")
            not_in_set2.add(item)
            good = False
    
    for item in set2:
        #print(item,"in set2 but not in set1")
        not_in_set1.add(item)
        good = False
        
    return good, not_in_set1, not_in_set2

# %% [markdown]
# # Check for Missing Data

# %%
#get metric list
files = []
for datadir in datadirs:
    files += [ os.path.join(datadir,x) for x in os.listdir(datadir) if (os.path.splitext(x)[-1] == ".nvprof") or (os.path.splitext(x)[-1] == ".nvvp") ]

#recs
records = []

#build feature list:
for path in files:
    
    #filename
    file = os.path.basename(path)
    
    #path
    path = os.path.dirname(path)
    
    #splitup
    splt = file.split(".")
    
    prefix = ".".join(splt[0:-2])
    metric = splt[-2].split("metric_")[1]
    
    #append to records
    records.append({"prefix": prefix, "metric": metric, "file": os.path.join(path, file)})

#put in df
recorddf = pd.DataFrame(records).sort_values(["prefix", "metric"])

#get all metrics
all_metrics = list(recorddf["metric"].unique())

#group by metric:
missingrecorddf = pd.DataFrame(recorddf.groupby("prefix").apply(lambda x: pd.Series([y for y in all_metrics if y not in list(x["metric"])])))

#create exclusion list:
excludelist = list(missingrecorddf.reset_index()["prefix"].unique())

#print the missing ones
missingrecorddf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-8830f4814146> in <module>
#      26
#      27 #put in df
# ---> 28 recorddf = pd.DataFrame(records).sort_values(["prefix", "metric"])
#      29
#      30 #get all metrics
#
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
#    4712             indexer = lexsort_indexer(keys, orders=ascending,
#    4713                                       na_position=na_position)
#
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4709
#    4710             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4711                     for x in by]
#    4712             indexer = lexsort_indexer(keys, orders=ascending,
#    4713                                       na_position=na_position)
#
# /usr/common/software/python/3.7-anaconda-2019.07/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'prefix'

# %% [markdown]
# # Read Kernels in each File

# %%
#sort by those keys:
sortkeys = ["Network Name", "Input Shape", "Kernel Shape", \
            "Batch Size", "Stride Size", "Data Format", "Pass", \
            "Precision", "Device", "Name", "Metric Name"]

#limit the input
#recorddf = recorddf[ recorddf["prefix"].str.startswith("profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32") ]

#group by prefixes and files
all_prefixes = set([x.split(".pass")[0] for x in recorddf["prefix"]])
all_metrics = recorddf["metric"].unique()
all_passes = set([x.split(".pass_")[1].replace(".pass_","") for x in recorddf["prefix"].unique()])

#metrics
df_profiles = []

for pref in all_prefixes:
    
    #loop over passes
    for pas in all_passes:
        
        #project frame
        selectdf = recorddf[ recorddf["prefix"] == pref + ".pass_" + pas ]
        
        if selectdf.empty:
            continue
        
        #loop over metrics
        df_summary = []
        for met in [x for x in all_metrics if x != "time"]:
            
            #filename
            file = selectdf.loc[ selectdf["metric"] == met, "file" ].values[0]
        
            #extract metric name
            parameters, metric = parse_filename(os.path.basename(file))
            metrics = metric.split("-")
        
            #import as summary
            tmpdf = import_nvprof_metric(file, timeline=False, cuda_dir=cudadir).sort_values(by="Name").reset_index(drop=True)
            for key in parameters:
                tmpdf[key] = parameters[key]
            del tmpdf["Metric Description"]
            tmpdf["Metric Name"] = met
            
            #append to summary
            df_summary.append(tmpdf)
        
        #concat
        metricdf = pd.concat(df_summary)
        metricdf = metricdf[ ["Name", "Metric Name"] ]
        
        #do time now
        file = selectdf.loc[ selectdf["metric"] == "time", "file" ].values[0]
        timedf, markerdf = import_nvprof_overview(file, cuda_dir=cudadir)
    
        #extract metric name
        parameters, _ = parse_filename(os.path.basename(file))
        for key in parameters:
            timedf[key] = parameters[key]
        
        #now, throw everything away but the kernel names and metric
        #also delete potential memcpy entry from the overview
        timedf = timedf.loc[ (timedf["Collection Type"]=="gpu_activities") & ~(timedf["Name"].str.contains("CUDA memcpy") | timedf["Name"].str.contains("CUDA memset")), ["Name"] ]
        
        #kernels
        kernels = set(timedf["Name"].unique())
        
        #now, for every metric, see if we have the same kernels as in the time df
        good = True
        for metric in metricdf["Metric Name"].unique():
            projdf = metricdf.loc[ metricdf["Metric Name"]==metric, ["Name"] ]
            tmpkernels = set(projdf["Name"].unique())
            
            tmpgood, not_in_set1, not_in_set2 = compare_sets(kernels, tmpkernels)
            good &= tmpgood
            
            if not tmpgood:
                print("discrepancy found:\n\tpass: {}\n \tmetric: {}\n \tprefix: {}\n".format(pas,metric,pref))
                print("kernels in time file but not in metric file:")
                for item in not_in_set2:
                    print("\t",item)
                print("\n")
                print("kernels in metric file but not in time file:")
                for item in not_in_set1:
                    print("\t",item)
                print("\n\n")
        #print(metricdf, timedf)
        
        #if all is good, move the files over to sanitized
        if good:
            for infile in selectdf["file"].unique():
                outfile = os.path.join(outputdir,os.path.basename(infile))
                #print(infile,outfile)
                shutil.move(infile,outfile)
# Out:
# discrepancy found:
# 	pass: forward
#  	metric: atomic_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: dram_write_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: flop_count_hp
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: flop_count_sp
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: gld_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: gst_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: l2_write_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: shared_store_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: sysmem_read_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: sysmem_write_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: forward
#  	metric: tensor_precision_fu_utilization
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 volta_gcgemm_32x32_nt
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
# kernels in metric file but not in time file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
#
# discrepancy found:
# 	pass: backward
#  	metric: dram_read_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
# kernels in metric file but not in time file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
#
# discrepancy found:
# 	pass: backward
#  	metric: dram_write_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
# kernels in metric file but not in time file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
#
# discrepancy found:
# 	pass: backward
#  	metric: l2_read_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
# kernels in metric file but not in time file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)
#
#
#
# discrepancy found:
# 	pass: backward
#  	metric: shared_load_transactions
#  	prefix: profile.name_ResNet50-2.batchsize_16.inputshape_112x112x64.kernelshape_7x7x64x64.stride_2.dataformat_NHWC.fp32
#
# kernels in time file but not in metric file:
# 	 volta_scudnn_128x64_relu_medium_nn_v1
# 	 cudnn::gemm::computeOffsetsKernel(cudnn::gemm::ComputeOffsetsParams)
#
#
# kernels in metric file but not in time file:
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=1, bool=1>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_r2c_32x32<float, bool=0, unsigned int=0, bool=0>(float2*, float const *, int, int, int, int, int, int, int, int, int, cudnn::reduced_divisor, bool, int2, int, int)
# 	 void fft2d_c2r_32x32<float, bool=1, bool=0, unsigned int=0, bool=0, bool=0>(float*, float2 const *, int, int, int, int, int, int, int, int, int, float, float, cudnn::reduced_divisor, bool, float*, float*, int2, int, int)

# %%
recorddf
# Out:
#                                                  file  \
# 10  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 19  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 23  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 13  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 1   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 15  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 7   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 18  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 26  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 20  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 5   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 17  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 8   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 12  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 29  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 25  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 22  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 2   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 4   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 16  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 6   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 11  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 3   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 24  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 0   ./data/tf_2.0b/investigate/profile.name_ResNet...
# 21  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 27  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 28  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 14  ./data/tf_2.0b/investigate/profile.name_ResNet...
# 9   ./data/tf_2.0b/investigate/profile.name_ResNet...
#
#                              metric  \
# 10              atomic_transactions
# 19           dram_read_transactions
# 23          dram_write_transactions
# 13                    flop_count_hp
# 1                     flop_count_sp
# 15                 gld_transactions
# 7                  gst_transactions
# 18             l2_read_transactions
# 26            l2_write_transactions
# 20         shared_load_transactions
# 5         shared_store_transactions
# 17         sysmem_read_transactions
# 8         sysmem_write_transactions
# 12  tensor_precision_fu_utilization
# 29                             time
# 25              atomic_transactions
# 22           dram_read_transactions
# 2           dram_write_transactions
# 4                     flop_count_hp
# 16                    flop_count_sp
# 6                  gld_transactions
# 11                 gst_transactions
# 3              l2_read_transactions
# 24            l2_write_transactions
# 0          shared_load_transactions
# 21        shared_store_transactions
# 27         sysmem_read_transactions
# 28        sysmem_write_transactions
# 14  tensor_precision_fu_utilization
# 9                              time
#
#                                                prefix
# 10  profile.name_ResNet50-2.batchsize_16.inputshap...
# 19  profile.name_ResNet50-2.batchsize_16.inputshap...
# 23  profile.name_ResNet50-2.batchsize_16.inputshap...
# 13  profile.name_ResNet50-2.batchsize_16.inputshap...
# 1   profile.name_ResNet50-2.batchsize_16.inputshap...
# 15  profile.name_ResNet50-2.batchsize_16.inputshap...
# 7   profile.name_ResNet50-2.batchsize_16.inputshap...
# 18  profile.name_ResNet50-2.batchsize_16.inputshap...
# 26  profile.name_ResNet50-2.batchsize_16.inputshap...
# 20  profile.name_ResNet50-2.batchsize_16.inputshap...
# 5   profile.name_ResNet50-2.batchsize_16.inputshap...
# 17  profile.name_ResNet50-2.batchsize_16.inputshap...
# 8   profile.name_ResNet50-2.batchsize_16.inputshap...
# 12  profile.name_ResNet50-2.batchsize_16.inputshap...
# 29  profile.name_ResNet50-2.batchsize_16.inputshap...
# 25  profile.name_ResNet50-2.batchsize_16.inputshap...
# 22  profile.name_ResNet50-2.batchsize_16.inputshap...
# 2   profile.name_ResNet50-2.batchsize_16.inputshap...
# 4   profile.name_ResNet50-2.batchsize_16.inputshap...
# 16  profile.name_ResNet50-2.batchsize_16.inputshap...
# 6   profile.name_ResNet50-2.batchsize_16.inputshap...
# 11  profile.name_ResNet50-2.batchsize_16.inputshap...
# 3   profile.name_ResNet50-2.batchsize_16.inputshap...
# 24  profile.name_ResNet50-2.batchsize_16.inputshap...
# 0   profile.name_ResNet50-2.batchsize_16.inputshap...
# 21  profile.name_ResNet50-2.batchsize_16.inputshap...
# 27  profile.name_ResNet50-2.batchsize_16.inputshap...
# 28  profile.name_ResNet50-2.batchsize_16.inputshap...
# 14  profile.name_ResNet50-2.batchsize_16.inputshap...
# 9   profile.name_ResNet50-2.batchsize_16.inputshap...
